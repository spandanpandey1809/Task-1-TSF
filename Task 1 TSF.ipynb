# %% [markdown]
# # TASK 1 - Prediction Using Supervised ML

# %% [markdown]
# **Predict the Percentage of Student based on the no. of study hours**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Fetching Data
data=pd.read_csv('http://bit.ly/w-data')
data.head(9)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81

# %%
#checking for null values in data set
data.isnull == True
# Out:
# False

# %%
sns.set_style('darkgrid')
sns.scatterplot(y= data['Scores'], x= data['Hours'])
plt.title('Marks Vs Study Hours',size=20)
plt.ylabel('Marks Percentage', size=15)
plt.xlabel('Hours Studied', size=15)
plt.show()

# %% [markdown]
# **Regression Plot between 'Marks Percentage' and 'Hours Studied'**

# %%
sns.regplot(x= data['Hours'], y= data['Scores'])
plt.title('Regression Plot',size=20)
plt.ylabel('Marks Percentage', size=15)
plt.xlabel('Hours Studied', size=15)
plt.show()

# %%
#finding correlation
print(data.corr())
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %% [markdown]
# ## Training the Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### 1) Splitting the Data

# %%
# Defining X and y from the Data
X = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values

# Spliting the Data in two
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

# %% [markdown]
# ### 2) Fitting the data into Model

# %%
regression = LinearRegression()
regression.fit(train_X, train_y)
print("---------Model Trained---------")
# Out:
# ---------Model Trained---------

# %% [markdown]
# ## Predicting Marks Percentage and Comparing it with Actual Marks

# %%
pred_y = regression.predict(val_X)
prediction = pd.DataFrame({'Hours': [i[0] for i in val_X], 'Predicted Marks': [k for k in pred_y]})
prediction
# Out:
#    Hours  Predicted Marks
# 0    1.5        16.844722
# 1    3.2        33.745575
# 2    7.4        75.500624
# 3    2.5        26.786400
# 4    5.9        60.588106
# 5    3.8        39.710582
# 6    1.9        20.821393

# %%
#Comparing Marks
compare_scores = pd.DataFrame({'Actual Marks': val_y, 'Predicted Marks': pred_y})
compare_scores
# Out:
#    Actual Marks  Predicted Marks
# 0            20        16.844722
# 1            27        33.745575
# 2            69        75.500624
# 3            30        26.786400
# 4            62        60.588106
# 5            35        39.710582
# 6            24        20.821393

# %% [markdown]
# ## Visually showing the Comparison

# %%
plt.scatter(x=val_X, y=val_y, color='blue')
plt.plot(val_X, pred_y, color='Black')
plt.title('Actual vs Predicted', size=20)
plt.ylabel('Marks Percentage', size=15)
plt.xlabel('Hours Studied', size=15)
plt.show()

# %% [markdown]
# ## Evaluating the Model

# %% [markdown]
# **Low value of Mean Absolute Error means Higher Accuracy**

# %%
from sklearn.metrics import mean_absolute_error

# %%
# Accuracy of Model
print('Mean absolute error: ',mean_absolute_error(val_y,pred_y))
# Out:
# Mean absolute error:  4.130879918502482

# %% [markdown]
# ## Predicting Score of a student who studies 9.25 hrs/ day

# %%
hours = [9.25]
answer = regression.predict([hours])
print("Score = {}".format(answer[0]))
# Out:
# Score = 93.89272889341652
